# %% [markdown]
# # Sanity Check (will be deleted when project complete)

# %%
from mia import DATASET_DIR
import pandas as pd
import os.path as osp
import numpy as np
from mia.utils import split_dataset

# %%
X_train, X_test, y_train, y_test = split_dataset('texas.npz', n_data=1000, random_seed=42, save_indices=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /users/xli321/data/xli321/mia/demo/vis_texas_dataset.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bccv-vscode-node/users/xli321/data/xli321/mia/demo/vis_texas_dataset.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> X_train, X_test, y_train, y_test = split_dataset('texas.npz', n_data=1000, random_seed=42, save_indices=True)
#
# File /oscar/data/mlittman/xli321/mia/mia/utils/dataset_splitter.py:36, in split_dataset(npz_file_name, n_data, test_size, random_seed, save_indices, load_indices_path)
#      33 np.random.seed(random_seed)
#      35 # Load the npz file
# ---> 36 data = np.load(DATASET_DIR + npz_file_name)
#      38 # Extract 'x' and 'y' data
#      39 X = data["x"]
#
# ...

# %%
file_name_1 = osp.join(DATASET_DIR, 'PUDF_base1q2006_tab.txt')
df1 = pd.read_csv(file_name_1, delimiter='\t')
df1.head()
# Out:
# /tmp/ipykernel_126424/243873187.py:2: DtypeWarning: Columns (3,4,5,6,7,8,9,10,14,15,17,18,24,25,26,29,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,94,97,98,100,103,106,109,112,115,118,121,124,127,168,169,170,171,172,177,178,179,180,185,186,187,188,189,190,191,192,193,194,195,197,199,201,209,210,211,212,213,214,221,223,225,227,229,231,233) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(file_name_1, delimiter='\t')
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q1       100  Austin State Hospital              NaN
# 1        2006Q1       100  Austin State Hospital              NaN
# 2        2006Q1       100  Austin State Hospital              NaN
# 3        2006Q1       100  Austin State Hospital              NaN
# 4        2006Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# ...

# %%
df1.describe()
# Out:
#             THCIC_ID  ENCOUNTER_INDICATOR         COUNTY  \
# count  732873.000000        732873.000000  711853.000000
# mean   359090.475795             1.005573     226.602716
# std    230743.006095             0.075062     142.395370
# min       100.000000             1.000000       1.000000
# 25%    154002.000000             1.000000     113.000000
# 50%    347000.000000             1.000000     201.000000
# 75%    497000.000000             1.000000     349.000000
# max    999999.000000             4.000000     507.000000
#
#        PUBLIC_HEALTH_REGION  ADMIT_WEEKDAY  LENGTH_OF_STAY        PAT_AGE  \
# count         711853.000000  732873.000000   732872.000000  732873.000000
# mean               5.770722       3.771831        5.414018      11.603979
# std                2.749869       2.077442       21.019842       6.932380
# min                1.000000       1.000000        1.000000       0.000000
# 25%                3.000000       2.000000        2.000000       7.000000
# ...

# %%
col1 = list(df1.columns)
for c in col1:
    if "STAY" in c:
        print(c)
# Out:
# LENGTH_OF_STAY
